# %%
import json

import joblib

# %%
list=joblib.load('list.pkl')

# %%
list
# Out:
# '```json\n[\n  {\n    "type": "Asset",\n    "Summary": "Slide Insurance stock skyrockets 15% on strong investor confidence.",\n    "link": "https://finance.yahoo.com/news/slide-insurance-slde-skyrockets-15-222200040.html",\n    "Name": "Slide Insurance",\n    "Ticker": "SLDE",\n    "impact": 2,\n    "timestamp": "2025-06-21T22:22:00"\n  },\n  {\n    "type": "Tag",\n    "Asset": "SLDE",\n    "Scope": "Insurance"\n  },\n  {\n    "type": "Location",\n    "Asset": "SLDE",\n    "Scope": "US"\n  },\n  {\n    "type": "Asset",\n    "Summary": "Bank of America predicts gold prices could reach $4,000 due to U.S. deficits and the Israel-Iran conflict.",\n    "link": "https://finance.yahoo.com/news/gold-prices-hit-4-000-193531068.html",\n    "Name": "Gold",\n    "Ticker": "GOLD",\n    "impact": 2,\n    "timestamp": "2025-06-21T19:35:31"\n  },\n  {\n    "type": "Tag",\n    "Asset": "GOLD",\n    "Scope": "Commodity"\n  },\n  {\n    "type": "Location",\n    "Asset": "GOLD",\n    "Scope": "Global"\n
# ...

# %%
l1=list.replace('```json','').replace('```','')

# %%
list_l=json.loads(l1)
list=list_l

# %%
import pandas as pd
types=['Tag','Asset','ScopeRelation','Scope','ScopeRelation','Macro','Location']

seprated_dfs={type:pd.DataFrame([e for e in list if e['type']==type]) for type in types}

# %%
seprated_dfs['Tag']
# Out:
#    type Asset                    Scope
# 0   Tag  SLDE                Insurance
# 1   Tag  GOLD                Commodity
# 2   Tag    SG              Food Retail
# 3   Tag  UNFI        Food Distribution
# 4   Tag   CAG          Food Production
# 5   Tag   GIS          Food Production
# 6   Tag   ACI                   Retail
# 7   Tag  FRPT                 Pet Food
# 8   Tag   SJM          Food Production
# 9   Tag  DNTH            Biotechnology
# 10  Tag  None             Cloud Mining
# 11  Tag  None                   Crypto
# 12  Tag   MEC            Manufacturing
# 13  Tag  HLIT     Broadband Technology
# 14  Tag  EFSC       Financial Services
# 15  Tag   SMA              Real Estate
# 16  Tag  CRCL        Internet Services
# 17  Tag   UAA         Retail (Apparel)
# 18  Tag  OSCR               Healthcare
# 19  Tag  ZETA  Artificial Intelligence
# 20  Tag   GXO                Logistics
# 21  Tag    KR         Retail (Grocery)
# 22  Tag  CRWV          Cloud Computing
# ...

# %%
seprated_dfs['Macro'].head()
# Out:
#     type                                            Summary  \
# 0  Macro  Bank of America predicts gold prices could rea...
# 1  Macro  Bank of America predicts gold prices could rea...
#
#                                                 link            Scope  \
# 0  https://finance.yahoo.com/news/gold-prices-hit...      Geopolitics
# 1  https://finance.yahoo.com/news/gold-prices-hit...  Government Debt
#
#   Location  impact            timestamp
# 0   Global       1  2025-06-21T19:35:31
# 1       US       1  2025-06-21T19:35:31

# %%
seprated_dfs['Scope']
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
seprated_dfs['ScopeRelation']
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
seprated_dfs['Location']
# Out:
#         type Asset   Scope
# 0   Location  SLDE      US
# 1   Location  GOLD  Global
# 2   Location    SG      US
# 3   Location  UNFI      US
# 4   Location   CAG      US
# 5   Location   GIS      US
# 6   Location   ACI      US
# 7   Location  FRPT      US
# 8   Location   SJM      US
# 9   Location  DNTH      US
# 10  Location  None  Global
# 11  Location   MEC      US
# 12  Location  HLIT  Global
# 13  Location  EFSC      US
# 14  Location   SMA      US
# 15  Location  CRCL      US
# 16  Location   UAA  Global
# 17  Location  OSCR      US
# 18  Location  ZETA  Global
# 19  Location   GXO  Global
# 20  Location    KR      US
# 21  Location  CRWV      US
# 22  Location  FANG      US
# 23  Location    HD      US
# 24  Location   AEP      US

# %%
#simulate db load

# %%
import os
max_age_hours = float(os.getenv("MAX_NEWS_AGE_HOURS", "48"))

# %%
assets=seprated_dfs['Asset']
assets['timestamp']=pd.to_datetime(assets['timestamp'])
assets.head()
# Out:
#     type                                            Summary  \
# 0  Asset  Slide Insurance stock skyrockets 15% on strong...
# 1  Asset  Bank of America predicts gold prices could rea...
# 2  Asset  Wells Fargo sees improving fundamentals for Sw...
# 3  Asset  BMO Capital lowers the price target for United...
# 4  Asset  UBS anticipates sluggish growth for Conagra Br...
#
#                                                 link  \
# 0  https://finance.yahoo.com/news/slide-insurance...
# 1  https://finance.yahoo.com/news/gold-prices-hit...
# 2  https://finance.yahoo.com/news/wells-fargo-see...
# 3  https://finance.yahoo.com/news/united-natural-...
# 4  https://finance.yahoo.com/news/ubs-sees-sluggi...
#
#                          Name Ticker  impact           timestamp
# 0             Slide Insurance   SLDE       2 2025-06-21 22:22:00
# 1                        Gold   GOLD       2 2025-06-21 19:35:31
# 2            Sweetgreen, Inc.     SG       2 2025-06-21 19:35:17
# ...

# %%
macro.head()
# Out:
#     type                                            Summary  \
# 0  Macro  Bank of America predicts gold prices could rea...
# 1  Macro  Bank of America predicts gold prices could rea...
#
#                                                 link            Scope  \
# 0  https://finance.yahoo.com/news/gold-prices-hit...      Geopolitics
# 1  https://finance.yahoo.com/news/gold-prices-hit...  Government Debt
#
#   Location  impact            timestamp
# 0   Global       1  2025-06-21T19:35:31
# 1       US       1  2025-06-21T19:35:31

# %%
macro=seprated_dfs['Macro']
#scope=seprated_dfs['Scope']
#scope['timestamp']=pd.to_datetime(scope['timestamp'])
macro['timestamp']=pd.to_datetime(macro['timestamp'])

# %%
from datetime import timedelta
most_recent_ts = assets['timestamp'].max()
cutoff=most_recent_ts-timedelta(hours=max_age_hours/2)

# %%
actual_assets = assets.loc[assets['timestamp']>cutoff]
history_assets = assets.loc[assets['timestamp']<cutoff]
actual_macro = macro.loc[macro['timestamp']>cutoff]
history_macro = macro.loc[macro['timestamp']<cutoff]
#actual_scope = scope.loc[scope['timestamp']>cutoff]
#history_scope = scope.loc[scope['timestamp']<cutoff]

# %%
#first, calculate the score for assets

# %%
assets=pd.concat([actual_assets,history_assets]).copy()
macro=pd.concat([actual_macro,history_macro]).copy()
#scope=pd.concat([actual_scope,history_scope])

# %%
assets['age']=(most_recent_ts-assets['timestamp']).apply(lambda x : x.total_seconds()/3600)
assets['age']
# Out:
# 0     10.486944
# 1     13.261667
# 2     13.265556
# 3     13.254167
# 4     13.203056
# 5     13.191389
# 6     13.168333
# 7     13.148056
# 8     13.123056
# 9     13.006111
# 10    12.965556
# 11    12.868611
# 12    12.843333
# 13    12.841111
# 14    12.772222
# 15    10.501944
# 16    10.469167
# 17    10.453611
# 18    10.436111
# 19    10.426667
# 20    10.417222
# 21    10.406667
# 22     0.037222
# 23     0.019722
# 24     0.000000
# Name: age, dtype: float64

# %%
0.99 ** 13
# Out:
# 0.8775210229989678

# %%
assets['w_impact']=(0.99 ** assets['age']) * assets['impact']

# %%
#propagate from macro
macro.head()
# Out:
#     type                                            Summary  \
# 0  Macro  Bank of America predicts gold prices could rea...
# 1  Macro  Bank of America predicts gold prices could rea...
#
#                                                 link            Scope  \
# 0  https://finance.yahoo.com/news/gold-prices-hit...      Geopolitics
# 1  https://finance.yahoo.com/news/gold-prices-hit...  Government Debt
#
#   Location  impact           timestamp
# 0   Global       1 2025-06-21 19:35:31
# 1       US       1 2025-06-21 19:35:31

# %%
scopes=seprated_dfs['Scope']

# %%
locations=seprated_dfs['Location']
locations.rename(columns={'Scope':'Location'}, inplace=True)
locations.drop(columns=['type'], inplace=True)
locations.head()
# Out:
#   Asset Location
# 0  SLDE       US
# 1  GOLD   Global
# 2    SG       US
# 3  UNFI       US
# 4   CAG       US

# %%
macro.drop('type',axis=1,inplace=True)
macro['age']=(most_recent_ts-macro['timestamp']).apply(lambda x : x.total_seconds()/3600)
macro['weight']=(0.99 ** macro['age']) * macro['impact']

# %%
# for the sake of simplicity, we connect macro only through location
#here we have the impacts of macro news on specific assets, based on the location of the company

macro_final=macro.merge(locations,on='Location', how='inner')

# %%
assets.head()
# Out:
#     type                                            Summary  \
# 0  Asset  Slide Insurance stock skyrockets 15% on strong...
# 1  Asset  Bank of America predicts gold prices could rea...
# 2  Asset  Wells Fargo sees improving fundamentals for Sw...
# 3  Asset  BMO Capital lowers the price target for United...
# 4  Asset  UBS anticipates sluggish growth for Conagra Br...
#
#                                                 link  \
# 0  https://finance.yahoo.com/news/slide-insurance...
# 1  https://finance.yahoo.com/news/gold-prices-hit...
# 2  https://finance.yahoo.com/news/wells-fargo-see...
# 3  https://finance.yahoo.com/news/united-natural-...
# 4  https://finance.yahoo.com/news/ubs-sees-sluggi...
#
#                          Name Ticker  impact           timestamp        age  \
# 0             Slide Insurance   SLDE       2 2025-06-21 22:22:00  10.486944
# 1                        Gold   GOLD       2 2025-06-21 19:35:31  13.261667
# ...

# %%
assets_final=assets[['Ticker','w_impact','link']]

# %%
macro_final=macro_final[['Asset','weight','link']]
macro_final.rename(columns={'Asset':'Ticker', 'weight':'w_impact'}, inplace=True)
# Out:
# C:\Users\ELTE\AppData\Local\Temp\ipykernel_37128\1743577104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   macro_final.rename(columns={'Asset':'Ticker', 'weight':'w_impact'}, inplace=True)

# %%
macro_final.head()
# Out:
#   Ticker  w_impact                                               link
# 0   GOLD  0.875216  https://finance.yahoo.com/news/gold-prices-hit...
# 1   None  0.875216  https://finance.yahoo.com/news/gold-prices-hit...
# 2   HLIT  0.875216  https://finance.yahoo.com/news/gold-prices-hit...
# 3    UAA  0.875216  https://finance.yahoo.com/news/gold-prices-hit...
# 4   ZETA  0.875216  https://finance.yahoo.com/news/gold-prices-hit...

# %%
res=pd.concat([assets_final,macro_final])

# %%
res.groupby('Ticker').agg({
    'w_impact': 'sum',  # Calculate mean for 'Value1'
    'link': (lambda x: ', '.join(x))   # Calculate sum for 'Value2'
})
# Out:
#         w_impact                                               link
# Ticker
# ACI     1.751254  https://finance.yahoo.com/news/albertsons-comp...
# AEP     2.875216  https://finance.yahoo.com/news/american-electr...
# CAG    -0.000516  https://finance.yahoo.com/news/ubs-sees-sluggi...
# CRCL    2.674879  https://finance.yahoo.com/news/circle-internet...
# CRWV    2.676603  https://finance.yahoo.com/news/coreweave-crwv-...
# DNTH    2.630151  https://finance.yahoo.com/news/stifel-reaffirm...
# EFSC    1.754140  https://finance.yahoo.com/news/enterprise-fina...
# FANG    2.874468  https://finance.yahoo.com/news/diamondback-ene...
# FRPT   -0.001000  https://finance.yahoo.com/news/ubs-says-future...
# GIS    -0.000618  https://finance.yahoo.com/news/wells-fargo-low...
# GOLD    2.625649  https://finance.yahoo.com/news/gold-prices-hit...
# GXO     2.676241  https://finance.yahoo.com/news/gxo-logistics-g...
# HD      2.874820  https://finance.yahoo.com/news/home-depot-divi...
# ...

# %%
### putting together

# %%
import pandas as pd
from datetime import timedelta



input_str=joblib.load('list.pkl')


def db_call(cut_time):
    pass


def process_analysis(input_str,db_simulation=False):
    #strip from junk
    input_str=input_str.replace('```json','').replace('```','')
    #str to list
    l=json.loads(input_str)
    #collected tables
    types=['Tag','Asset','ScopeRelation','Scope','ScopeRelation','Macro','Location']
    # table dataframes from the input
    seprated_dfs={type:pd.DataFrame([e for e in l if e['type']==type]) for type in types}
    #for  npw we only use assets, locations and macro for demontration purpose
    macro=seprated_dfs['Macro']
    macro.drop(columns=['type'],inplace=True)
    macro['timestamp']=pd.to_datetime(macro['timestamp'])

    assets=seprated_dfs['Asset']
    assets.drop(columns=['type'],inplace=True)
    assets['timestamp']=pd.to_datetime(assets['timestamp'])

    locations=seprated_dfs['Location']
    locations.rename(columns={'Scope':'Location'}, inplace=True)
    locations.drop(columns=['type'], inplace=True)
    
    most_recent_ts = assets['timestamp'].max()
    max_age_hours = float(os.getenv("MAX_NEWS_AGE_HOURS", "48"))
    if db_simulation:
        cutoff=most_recent_ts-timedelta(hours=max_age_hours/2)
        actual_assets = assets.loc[assets['timestamp']>cutoff]
        history_assets = assets.loc[assets['timestamp']<cutoff]
        actual_macro = macro.loc[macro['timestamp']>cutoff]
        history_macro = macro.loc[macro['timestamp']<cutoff]
        assets=actual_assets
        macro=actual_macro
    else:
        history_macro,history_assets=db_call(cut_time=os.getenv())
    
    assets=pd.concat([actual_assets,history_assets]).copy()
    macro=pd.concat([actual_macro,history_macro]).copy()
    
    
    macro['age']=(most_recent_ts-macro['timestamp']).apply(lambda x : x.total_seconds()/3600)
    macro['weight']=(0.99 ** macro['age']) * macro['impact']
    
    assets['age']=(most_recent_ts-assets['timestamp']).apply(lambda x : x.total_seconds()/3600)
    assets['weight']=(0.99 ** assets['age']) * assets['impact']

    assets_final = assets[['Ticker', 'weight', 'link']]
    
    #location decribes a localisation of the asset, this what we use as an example for proőpagation
    macro_final=macro.merge(locations,on='Location', how='inner')

    macro_final = macro_final[['Asset', 'weight', 'link']]
    macro_final.rename(columns={'Asset':'Ticker', 'weight':'w_impact'}, inplace=True)
    res = pd.concat([assets_final, macro_final])


    return res.groupby('Ticker').agg({
        'weight': 'sum',  
        'link': (lambda x: ', '.join(x))  
    })
        


process_analysis(input_str,db_simulation=True)
# Out:
#           weight                                               link
# Ticker
# ACI     0.876038  https://finance.yahoo.com/news/albertsons-comp...
# AEP     2.000000  https://finance.yahoo.com/news/american-electr...
# CAG    -0.875732  https://finance.yahoo.com/news/ubs-sees-sluggi...
# CRCL    1.799662  https://finance.yahoo.com/news/circle-internet...
# CRWV    1.801387  https://finance.yahoo.com/news/coreweave-crwv-...
# DNTH    1.754934  https://finance.yahoo.com/news/stifel-reaffirm...
# EFSC    0.878923  https://finance.yahoo.com/news/enterprise-fina...
# FANG    1.999252  https://finance.yahoo.com/news/diamondback-ene...
# FRPT   -0.876216  https://finance.yahoo.com/news/ubs-says-future...
# GIS    -0.875835  https://finance.yahoo.com/news/wells-fargo-low...
# GOLD    1.750433  https://finance.yahoo.com/news/gold-prices-hit...
# GXO     1.801025  https://finance.yahoo.com/news/gxo-logistics-g...
# HD      1.999604  https://finance.yahoo.com/news/home-depot-divi...
# ...

# %%
import requests
from bs4 import BeautifulSoup
from newspaper import Article, ArticleException
import time
import random
import json
from datetime import datetime, timezone # Import for datetime handling

debug_article_loc="./scrap"

def get_yahoo_finance_general_news_articles(num_pages=3, since_datetime=None):
    """
    Scrapes general financial news headlines and links from Yahoo Finance,
    then attempts to download and extract the full text and metadata for each article.
    Filters articles to include only those published after a specified datetime.

    Args:
        num_pages (int): The maximum number of pages of news to scrape from Yahoo Finance.
                         Each page typically contains multiple article links.
                         Scraping might stop earlier if older articles are encountered.
        since_datetime (datetime.datetime, optional): A datetime object. Only articles
                                                     published ON or AFTER this datetime
                                                     will be returned. If None, all found
                                                     articles within num_pages are returned.

    Returns:
        list: A list of dictionaries, where each dictionary represents an article
              with keys like 'title', 'link', 'published_date', 'authors', and 'text'.
    """
    base_url = "https://finance.yahoo.com/news/"
    all_articles_data = []

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }

    print(f"--- Starting Yahoo Finance General News Article Scraper ---")
    print(f"Attempting to scrape up to {num_pages} page(s) of news.")
    if since_datetime:
        print(f"Filtering for articles published after: {since_datetime.isoformat()}")

    # Track if we've encountered an article older than since_datetime on a page
    found_old_article = False

    for i in range(num_pages):
        if found_old_article:
            print("Stopping scraping as an article older than the specified datetime was found on the previous page.")
            break

        offset = i * 25
        url = f"{base_url}?count=25&offset={offset}"

        try:
            # Step 1: Get the list of news article links from Yahoo Finance news page
            print(f"Fetching page {i+1}/{num_pages} from {url}...")
            response = requests.get(url, headers=headers, timeout=10)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'html.parser')

            news_items = soup.find_all('li', class_='stream-item') # Adjust this class if Yahoo changes its HTML
            
            if not news_items:
                print(f"No news items found on page {i+1}. Stopping further scraping.")
                break

            print(f"  Found {len(news_items)} potential articles on page {i+1}.")
            i =0

            for item in news_items:
                link_tag = item.find('a', class_='subtle-link')
                if link_tag and link_tag.get('href'):
                    article_url = link_tag['href']
                    if not article_url.startswith('http'):
                        article_url = "https://finance.yahoo.com" + article_url
                    
                    try:
                        article = Article(article_url)
                        article.download()
                        article.parse()
                        article_published_date = None
                        if article.publish_date:
                            
                            # newspaper3k often returns timezone-naive datetimes.
                            # We make it timezone-aware (UTC) for consistent comparison.
                            # Adjust this if Yahoo Finance provides timezone info in its dates.
                            article_published_date = article.publish_date.replace(tzinfo=timezone.utc)
                            # print(f"    - Article '{article.title}' published: {article_published_date.isoformat()}")
                        else:
                            print(f"NO DATETIME: {article_url}")
                            try:
                        
                                article_meta_data = article.meta_data
                                """
                                article_title = [value['title'] for (key, value) in article_meta_data.items() if key == 'og']
                                print(article_title)
                            
                                article_published_date = [value['recs']['publishtime'] for key, value in article_meta_data.items()
                                                          if key == 'cXenseParse']
                                print(article_published_date)
                            
                                article_description = [value['description'] for (key, value) in article_meta_data.items() if key == 'og']
                                print(article_description)
                                """
                                with open(f"{debug_article_loc}/failed_meta{i}.json", "w", encoding="utf-8") as file:
                                    json.dumps(article_meta_data)
                            
                            except ArticleException as error:
                                print(error)

                          
                            with open(f"{debug_article_loc}/failed{i}.html", "w", encoding="utf-8") as file:
                                file.write(article.html)
                            i+=1
                        # Check if the article is fresh enough
                        if since_datetime and article_published_date and article_published_date < since_datetime:
                            print(f"    - Article '{article.title}' is too old ({article_published_date.isoformat()}). Stopping page processing.")
                            found_old_article = True # Mark to stop outer loop
                            break # Stop processing articles on this page
                        
                        # Only add if it's new enough or no filter is applied
                        article_data = {
                            "title": article.title,
                            "link": article_url,
                            "published_date": str(article_published_date) if article_published_date else None,
                            "authors": article.authors,
                            "text": article.text
                        }
                        all_articles_data.append(article_data)
                        # print(f"    - Added: '{article.title}'")

                    except ArticleException as ae:
                        print(f"    - Could not process article at {article_url}: {ae}")
                    except Exception as sub_e:
                        print(f"    - An unexpected error processing {article_url}: {sub_e}")
                
                time.sleep(random.uniform(0.5, 1.5)) # Small delay between processing articles on a page

            print(f"Finished processing page {i+1}.")
            time.sleep(random.uniform(2, 5)) # Polite delay between pages

        except requests.exceptions.RequestException as e:
            print(f"Error fetching Yahoo Finance news page {i+1}: {e}")
            break
        except Exception as e:
            print(f"An unexpected error occurred while processing page {i+1}: {e}")
            break

    print(f"--- Finished News Scraping. Total fresh articles extracted: {len(all_articles_data)} ---")
    return all_articles_data
"""
if __name__ == "__main__":
    print("This script is designed to be used by a Gemini Agent.")
    print("Running a test example directly...")
    
    # --- Test Case 1: Fetch all recent articles (e.g., last 24 hours) ---
    # To get articles from the last 24 hours:
    # 1. Get current time
    # 2. Subtract 24 hours
    # 3. Ensure it's timezone-aware (UTC is a good default for comparison)
    
    # Convert the current time to a datetime object in UTC
    # Current time (Monday, June 23, 2025 at 7:12:01 PM CEST)
    # Let's use a fixed current time for reproducibility for testing purposes
    # In a real agent scenario, you would use datetime.utcnow() or similar.
    # For this example, let's pretend "now" is June 23, 2025, 7 PM CEST,
    # which is 5 PM UTC (CEST is UTC+2)
    
    current_utc_time = datetime(2025, 6, 23, 17, 12, 1, tzinfo=timezone.utc)
    
    # Example: Get articles from the last 24 hours
    from datetime import timedelta
    since_24_hours_ago = current_utc_time - timedelta(hours=24)
    print(f"\n--- Testing with articles after: {since_24_hours_ago.isoformat()} ---")
    recent_articles = get_yahoo_finance_general_news_articles(num_pages=2, since_datetime=since_24_hours_ago)
    
    if recent_articles:
        print(f"\n--- Sample of {min(3, len(recent_articles))} Recent Articles ---")
        for i, article in enumerate(recent_articles[:3]):
            print(f"\nArticle {i+1}:")
            print(f"  Title: {article.get('title', 'N/A')}")
            print(f"  Link: {article.get('link', 'N/A')}")
            print(f"  Published Date: {article.get('published_date', 'N/A')}")
            # print(f"  Authors: {', '.join(article.get('authors', ['N/A']))}")
            # print(f"  Text (excerpt): {article.get('text', 'N/A')[:200]}...")
    else:
        print("\nNo recent articles found for the test period.")

    print("\n--- Test complete. ---")
"""
# Out:
# '\nif __name__ == "__main__":\n    print("This script is designed to be used by a Gemini Agent.")\n    print("Running a test example directly...")\n\n    # --- Test Case 1: Fetch all recent articles (e.g., last 24 hours) ---\n    # To get articles from the last 24 hours:\n    # 1. Get current time\n    # 2. Subtract 24 hours\n    # 3. Ensure it\'s timezone-aware (UTC is a good default for comparison)\n\n    # Convert the current time to a datetime object in UTC\n    # Current time (Monday, June 23, 2025 at 7:12:01 PM CEST)\n    # Let\'s use a fixed current time for reproducibility for testing purposes\n    # In a real agent scenario, you would use datetime.utcnow() or similar.\n    # For this example, let\'s pretend "now" is June 23, 2025, 7 PM CEST,\n    # which is 5 PM UTC (CEST is UTC+2)\n\n    current_utc_time = datetime(2025, 6, 23, 17, 12, 1, tzinfo=timezone.utc)\n\n    # Example: Get articles from the last 24 hours\n    from datetime import timedelta\n    since_24_hours_ago = 
# ...

# %%
current_utc_time = datetime.now(timezone.utc)

# Example: Get articles from the last 24 hours
from datetime import timedelta
since_24_hours_ago = current_utc_time - timedelta(hours=24)
print(f"\n--- Testing with articles after: {since_24_hours_ago.isoformat()} ---")
recent_articles = get_yahoo_finance_general_news_articles(num_pages=2, since_datetime=since_24_hours_ago)

if recent_articles:
    print(f"\n--- Sample of {min(3, len(recent_articles))} Recent Articles ---")
    for i, article in enumerate(recent_articles[:3]):
        print(f"\nArticle {i+1}:")
        print(f"  Title: {article.get('title', 'N/A')}")
        print(f"  Link: {article.get('link', 'N/A')}")
        print(f"  Published Date: {article.get('published_date', 'N/A')}")
        # print(f"  Authors: {', '.join(article.get('authors', ['N/A']))}")
        # print(f"  Text (excerpt): {article.get('text', 'N/A')[:200]}...")
else:
    print("\nNo recent articles found for the test period.")

print("\n--- Test complete. ---")
# Out:
# --- Testing with articles after: 2025-06-25T05:24:59.621443+00:00 ---
# --- Starting Yahoo Finance General News Article Scraper ---
# Attempting to scrape up to 2 page(s) of news.
# Filtering for articles published after: 2025-06-25T05:24:59.621443+00:00
# Fetching page 1/2 from https://finance.yahoo.com/news/?count=25&offset=0...
#   Found 12 potential articles on page 1.
# NO DATETIME: https://finance.yahoo.com/news/autozone-inc-azo-bull-case-173217818.html
# NO DATETIME: https://finance.yahoo.com/news/remitly-global-inc-rely-bull-173621048.html
# NO DATETIME: https://finance.yahoo.com/news/applied-digital-corporation-apld-bull-173423933.html
# NO DATETIME: https://finance.yahoo.com/news/exelon-corp-exc-draws-bullish-173002912.html
# NO DATETIME: https://finance.yahoo.com/news/expert-grow-investments-100k-5-173506664.html
# NO DATETIME: https://finance.yahoo.com/research/reports/MS_0P000004RX_AnalystReport_1750898311000?yptr=yahoo&ncid=yahooproperties_plusresear_nm5q6ze1cei
# ...

# %%
test_tss=['Moneywise • 1 hour ago', 'The Accountant • 7 minutes ago', "Investor's Business Daily • 13 minutes ago", 'Bankrate • 21 minutes ago', 'Bankrate • 32 minutes ago', 'Morningstar Research • 1 hour ago', 'FreightWaves • 36 minutes ago', 'World Construction Network • 19 minutes ago', "Investor's Business Daily • 36 minutes ago", 'Bankrate • 38 minutes ago', 'Reuters • 6 minutes ago', 'The Accountant • 7 minutes ago', "Investor's Business Daily • 14 minutes ago", 'Bankrate • 21 minutes ago', 'Bankrate • 32 minutes ago', 'Morningstar Research • 1 hour ago', 'FreightWaves • 36 minutes ago', 'Bloomberg • 20 minutes ago', "Investor's Business Daily • 36 minutes ago", 'Bankrate • 39 minutes ago', 'Bankrate • yesterday', 'Bankrate • 2 hours ago', 'Bankrate • 1 month ago', 'Bankrate • 2 months ago', 'Bankrate • 2 weeks ago']

# %%
import re
pattern = r'\b(\d+\s(?:hours?|minutes?|days?|weeks?|months?)\sago|yesterday)\b'

for i in test_tss:

    # Find all matches
    matches = re.findall(pattern, i)
    
    # Print results
    print(i, " => ",matches)
# Out:
# Moneywise • 1 hour ago  =>  ['1 hour ago']
# The Accountant • 7 minutes ago  =>  ['7 minutes ago']
# Investor's Business Daily • 13 minutes ago  =>  ['13 minutes ago']
# Bankrate • 21 minutes ago  =>  ['21 minutes ago']
# Bankrate • 32 minutes ago  =>  ['32 minutes ago']
# Morningstar Research • 1 hour ago  =>  ['1 hour ago']
# FreightWaves • 36 minutes ago  =>  ['36 minutes ago']
# World Construction Network • 19 minutes ago  =>  ['19 minutes ago']
# Investor's Business Daily • 36 minutes ago  =>  ['36 minutes ago']
# Bankrate • 38 minutes ago  =>  ['38 minutes ago']
# Reuters • 6 minutes ago  =>  ['6 minutes ago']
# The Accountant • 7 minutes ago  =>  ['7 minutes ago']
# Investor's Business Daily • 14 minutes ago  =>  ['14 minutes ago']
# Bankrate • 21 minutes ago  =>  ['21 minutes ago']
# Bankrate • 32 minutes ago  =>  ['32 minutes ago']
# Morningstar Research • 1 hour ago  =>  ['1 hour ago']
# FreightWaves • 36 minutes ago  =>  ['36 minutes ago']
# ...

# %%
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

def convert_to_timestamp(relative_time):
    now = datetime.now()

    if "minute" in relative_time:
        minutes = int(relative_time.split()[0])
        return (now - timedelta(minutes=minutes)).strftime('%Y-%m-%d %H:%M:%S')

    elif "hour" in relative_time:
        hours = int(relative_time.split()[0])
        return (now - timedelta(hours=hours)).strftime('%Y-%m-%d %H:%M:%S')

    elif "yesterday" in relative_time:
        return (now - timedelta(days=1)).strftime('%Y-%m-%d %H:%M:%S')

    elif "day" in relative_time:
        days = int(relative_time.split()[0])
        return (now - timedelta(days=days)).strftime('%Y-%m-%d %H:%M:%S')
    elif "week" in relative_time:
        weeks = int(relative_time.split()[0])
        return (now - timedelta(days=weeks*7)).strftime('%Y-%m-%d %H:%M:%S')
    elif "month" in relative_time:
        days = int(relative_time.split()[0])
        return (now - timedelta(days=days)).strftime('%Y-%m-%d %H:%M:%S')

    else:
        raise ValueError("Unsupported time format", relative_time)

# Examples
print(convert_to_timestamp("3 hours ago"))  # Example: '2025-07-07 09:30:00'
print(convert_to_timestamp("yesterday"))   # Example: '2025-07-06 12:30:00'
print(convert_to_timestamp("2 days ago"))  # Example: '2025-07-05 12:30:00'
print(convert_to_timestamp("30 minutes ago"))  # Example: '2025-07-07 12:00:00'
# Out:
# 2025-07-07 16:37:11
# 2025-07-06 19:37:11
# 2025-07-05 19:37:11
# 2025-07-07 19:07:11

# %%
for i in test_tss:

    # Find all matches
    matches = re.findall(pattern, i)
    print(i, "=>",convert_to_timestamp(matches[0]))
# Out:
# Moneywise • 1 hour ago => 2025-07-07 18:38:09
# The Accountant • 7 minutes ago => 2025-07-07 19:31:09
# Investor's Business Daily • 13 minutes ago => 2025-07-07 19:25:09
# Bankrate • 21 minutes ago => 2025-07-07 19:17:09
# Bankrate • 32 minutes ago => 2025-07-07 19:06:09
# Morningstar Research • 1 hour ago => 2025-07-07 18:38:09
# FreightWaves • 36 minutes ago => 2025-07-07 19:02:09
# World Construction Network • 19 minutes ago => 2025-07-07 19:19:09
# Investor's Business Daily • 36 minutes ago => 2025-07-07 19:02:09
# Bankrate • 38 minutes ago => 2025-07-07 19:00:09
# Reuters • 6 minutes ago => 2025-07-07 19:32:09
# The Accountant • 7 minutes ago => 2025-07-07 19:31:09
# Investor's Business Daily • 14 minutes ago => 2025-07-07 19:24:09
# Bankrate • 21 minutes ago => 2025-07-07 19:17:09
# Bankrate • 32 minutes ago => 2025-07-07 19:06:09
# Morningstar Research • 1 hour ago => 2025-07-07 18:38:09
# FreightWaves • 36 minutes ago => 2025-07-07 19:02:09
# ...
